# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kamy Muissa__
# Revenue Assurance Manager

# %% [markdown]
# _I am interested in data science because I like to play with Data
# I know that data plays an important role in every business today,
# so I love learning how to work with data in all its forms and use it to transform the business_

# %% [markdown]
# ### The following code calculates the sum of two numbers entered as arguments

# %%
def sum(a, b):
    return (a + b)

a = int(input('Enter 1st number: '))
b = int(input('Enter 2nd number: '))

print(f'Sum of {a} and {b} is {sum(a, b)}')
# Out:
# Enter 1st number: 10
# Enter 2nd number: 20
# Sum of 10 and 20 is 30

# %% [markdown]
# Fisrt five letters of alphabet
# - A
# - B
# - C
# - D
# - E
#
#
# Then a litle table
#
# |  Syntax    | Description |
# | ---------- |-------------|
# |  Header    | Title       |
# |  Paragraph | Text        |
#
#
#
#
#
# And now an hyperlink to the ibm website
#
# https://www.ibm.com
